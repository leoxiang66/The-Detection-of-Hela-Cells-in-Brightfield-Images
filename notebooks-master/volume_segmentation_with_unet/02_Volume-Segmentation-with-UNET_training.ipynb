# %%
# Youtube: https://www.youtube.com/watch?v=CogGIdkDA8g

# %%
import os
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow import keras

# %%
# Define constants
SEED = 909
BATCH_SIZE_TRAIN = 32
BATCH_SIZE_TEST = 32

IMAGE_HEIGHT = 40
IMAGE_WIDTH = 80
IMG_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)

data_dir = 'data/slices/'
data_dir_train = os.path.join(data_dir, 'training')
# The images should be stored under: "data/slices/training/img/img"
data_dir_train_image = os.path.join(data_dir_train, 'img')
# The images should be stored under: "data/slices/training/mask/img"
data_dir_train_mask = os.path.join(data_dir_train, 'mask')

data_dir_test = os.path.join(data_dir, 'test')
# The images should be stored under: "data/slices/test/img/img"
data_dir_test_image = os.path.join(data_dir_test, 'img')
# The images should be stored under: "data/slices/test/mask/img"
data_dir_test_mask = os.path.join(data_dir_test, 'mask')

NUM_TRAIN = 360
NUM_TEST = 100

NUM_OF_EPOCHS = 100

# %%
def create_segmentation_generator_train(img_path, msk_path, BATCH_SIZE):
    data_gen_args = dict(rescale=1./255
#                      featurewise_center=True,
#                      featurewise_std_normalization=True,
#                      rotation_range=90
#                      width_shift_range=0.2,
#                      height_shift_range=0.2,
#                      zoom_range=0.3
                        )
    datagen = ImageDataGenerator(**data_gen_args)
    
    img_generator = datagen.flow_from_directory(img_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    msk_generator = datagen.flow_from_directory(msk_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    return zip(img_generator, msk_generator)

# Remember not to perform any image augmentation in the test generator!
def create_segmentation_generator_test(img_path, msk_path, BATCH_SIZE):
    data_gen_args = dict(rescale=1./255)
    datagen = ImageDataGenerator(**data_gen_args)
    
    img_generator = datagen.flow_from_directory(img_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    msk_generator = datagen.flow_from_directory(msk_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    return zip(img_generator, msk_generator)

# %%
train_generator = create_segmentation_generator_train(data_dir_train_image, data_dir_train_mask, BATCH_SIZE_TRAIN)
test_generator = create_segmentation_generator_test(data_dir_test_image, data_dir_test_mask, BATCH_SIZE_TEST)
# Out:
# Found 150 images belonging to 1 classes.
# Found 150 images belonging to 1 classes.
# Found 30 images belonging to 1 classes.
# Found 30 images belonging to 1 classes.

# %%
def display(display_list):
    plt.figure(figsize=(15,15))
    
    title = ['Input Image', 'True Mask', 'Predicted Mask']
    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap='gray')
    plt.show()

# %%
def show_dataset(datagen, num=1):
    for i in range(0,num):
        image,mask = next(datagen)
        display([image[0], mask[0]])

# %%
show_dataset(train_generator, 2)

# %%
def unet(n_levels, initial_features=32, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=1, out_channels=1):
    inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
    x = inputs
    
    convpars = dict(kernel_size=kernel_size, activation='relu', padding='same')
    
    #downstream
    skips = {}
    for level in range(n_levels):
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
        if level < n_levels - 1:
            skips[level] = x
            x = keras.layers.MaxPool2D(pooling_size)(x)
            
    # upstream
    for level in reversed(range(n_levels-1)):
        x = keras.layers.Conv2DTranspose(initial_features * 2 ** level, strides=pooling_size, **convpars)(x)
        x = keras.layers.Concatenate()([x, skips[level]])
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
            
    # output
    activation = 'sigmoid' if out_channels == 1 else 'softmax'
    x = keras.layers.Conv2D(out_channels, kernel_size=1, activation=activation, padding='same')(x)
    
    return keras.Model(inputs=[inputs], outputs=[x], name=f'UNET-L{n_levels}-F{initial_features}')

# %%
EPOCH_STEP_TRAIN = NUM_TRAIN // BATCH_SIZE_TRAIN
EPOCH_STEP_TEST = NUM_TEST // BATCH_SIZE_TEST

model = unet(4)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "UNET-L4-F32"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 40, 80, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 40, 80, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 40, 80, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 20, 40, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 20, 40, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 40, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 10, 20, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 10, 20, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 10, 20, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 10, 128)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 5, 10, 256)   295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 5, 10, 256)   590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 10, 20, 128)  295040      conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 20, 256)  0           conv2d_transpose[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 20, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 20, 128)  147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 20, 40, 64)   73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 40, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 40, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 40, 64)   36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 40, 80, 32)   18464       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40, 80, 64)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 40, 80, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 40, 80, 32)   9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 40, 80, 1)    33          conv2d_13[0][0]
# ==================================================================================================
# Total params: 2,140,065
# Trainable params: 2,140,065
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit_generator(generator=train_generator, 
                    steps_per_epoch=EPOCH_STEP_TRAIN, 
                    validation_data=test_generator, 
                    validation_steps=EPOCH_STEP_TEST,
                   epochs=NUM_OF_EPOCHS)
# Out:
# Epoch 1/100
# /Users/taoxiang/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 11/11 [==============================] - 10s 793ms/step - loss: 0.6319 - accuracy: 0.7989 - val_loss: 0.5634 - val_accuracy: 0.8404
# Epoch 2/100
# 11/11 [==============================] - 8s 753ms/step - loss: 0.4422 - accuracy: 0.8558 - val_loss: 0.4975 - val_accuracy: 0.8404
# Epoch 3/100
# 11/11 [==============================] - 9s 791ms/step - loss: 0.4208 - accuracy: 0.8580 - val_loss: 0.4538 - val_accuracy: 0.8404
# Epoch 4/100
# 11/11 [==============================] - 7s 663ms/step - loss: 0.4100 - accuracy: 0.8585 - val_loss: 0.4215 - val_accuracy: 0.8404
# Epoch 5/100
# 11/11 [==============================] - 7s 663ms/step - loss: 0.4151 - accuracy: 0.8534 - val_loss: 0.4105 - val_accuracy: 0.8404
# Epoch 6/100
# 11/11 [==============================] - 7s 654ms/step - loss: 0.4093 - accuracy: 0.8557 - val_loss: 0.4113 - val_accuracy: 0.8404
# Epoch 7/100
# 11/11 [==============================] - 7s 662ms/step - loss: 0.4034 - accuracy: 0.8590 - val_loss: 0.4160 - val_accuracy: 0.8404
# Epoch 8/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.4117 - accuracy: 0.8542 - val_loss: 0.4188 - val_accuracy: 0.8404
# Epoch 9/100
# 11/11 [==============================] - 7s 673ms/step - loss: 0.4109 - accuracy: 0.8548 - val_loss: 0.4198 - val_accuracy: 0.8404
# Epoch 10/100
# 11/11 [==============================] - 7s 674ms/step - loss: 0.4048 - accuracy: 0.8578 - val_loss: 0.4204 - val_accuracy: 0.8404
# Epoch 11/100
# 11/11 [==============================] - 7s 660ms/step - loss: 0.4067 - accuracy: 0.8570 - val_loss: 0.4226 - val_accuracy: 0.8404
# Epoch 12/100
# 11/11 [==============================] - 9s 785ms/step - loss: 0.4053 - accuracy: 0.8579 - val_loss: 0.4248 - val_accuracy: 0.8404
# Epoch 13/100
# 11/11 [==============================] - 9s 845ms/step - loss: 0.4072 - accuracy: 0.8567 - val_loss: 0.4194 - val_accuracy: 0.8404
# Epoch 14/100
# 11/11 [==============================] - 8s 738ms/step - loss: 0.4052 - accuracy: 0.8575 - val_loss: 0.4205 - val_accuracy: 0.8404
# Epoch 15/100
# 11/11 [==============================] - 7s 672ms/step - loss: 0.4026 - accuracy: 0.8590 - val_loss: 0.4224 - val_accuracy: 0.8404
# Epoch 16/100
# 11/11 [==============================] - 7s 662ms/step - loss: 0.4051 - accuracy: 0.8580 - val_loss: 0.4233 - val_accuracy: 0.8404
# Epoch 17/100
# 11/11 [==============================] - 8s 685ms/step - loss: 0.4036 - accuracy: 0.8585 - val_loss: 0.4225 - val_accuracy: 0.8404
# Epoch 18/100
# 11/11 [==============================] - 7s 681ms/step - loss: 0.4088 - accuracy: 0.8558 - val_loss: 0.4212 - val_accuracy: 0.8404
# Epoch 19/100
# 11/11 [==============================] - 7s 677ms/step - loss: 0.4122 - accuracy: 0.8540 - val_loss: 0.4246 - val_accuracy: 0.8404
# Epoch 20/100
# 11/11 [==============================] - 8s 777ms/step - loss: 0.4042 - accuracy: 0.8583 - val_loss: 0.4217 - val_accuracy: 0.8404
# Epoch 21/100
# 11/11 [==============================] - 7s 659ms/step - loss: 0.4171 - accuracy: 0.8519 - val_loss: 0.4200 - val_accuracy: 0.8404
# Epoch 22/100
# 11/11 [==============================] - 7s 678ms/step - loss: 0.4068 - accuracy: 0.8564 - val_loss: 0.4224 - val_accuracy: 0.8404
# Epoch 23/100
# 11/11 [==============================] - 7s 671ms/step - loss: 0.4088 - accuracy: 0.8552 - val_loss: 0.4217 - val_accuracy: 0.8404
# Epoch 24/100
# 11/11 [==============================] - 7s 663ms/step - loss: 0.4075 - accuracy: 0.8563 - val_loss: 0.4239 - val_accuracy: 0.8404
# Epoch 25/100
# 11/11 [==============================] - 7s 681ms/step - loss: 0.4090 - accuracy: 0.8554 - val_loss: 0.4227 - val_accuracy: 0.8404
# Epoch 26/100
# 11/11 [==============================] - 7s 664ms/step - loss: 0.4108 - accuracy: 0.8543 - val_loss: 0.4228 - val_accuracy: 0.8404
# Epoch 27/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.4099 - accuracy: 0.8545 - val_loss: 0.4266 - val_accuracy: 0.8404
# Epoch 28/100
# 11/11 [==============================] - 7s 679ms/step - loss: 0.3999 - accuracy: 0.8603 - val_loss: 0.4222 - val_accuracy: 0.8404
# Epoch 29/100
# 11/11 [==============================] - 7s 659ms/step - loss: 0.4074 - accuracy: 0.8558 - val_loss: 0.4252 - val_accuracy: 0.8404
# Epoch 30/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.4037 - accuracy: 0.8573 - val_loss: 0.4286 - val_accuracy: 0.8404
# Epoch 31/100
# 11/11 [==============================] - 7s 650ms/step - loss: 0.4060 - accuracy: 0.8550 - val_loss: 0.4294 - val_accuracy: 0.8404
# Epoch 32/100
# 11/11 [==============================] - 7s 658ms/step - loss: 0.3967 - accuracy: 0.8592 - val_loss: 0.4336 - val_accuracy: 0.8404
# Epoch 33/100
# 11/11 [==============================] - 7s 660ms/step - loss: 0.3965 - accuracy: 0.8604 - val_loss: 0.4291 - val_accuracy: 0.8404
# Epoch 34/100
# 11/11 [==============================] - 7s 629ms/step - loss: 0.3981 - accuracy: 0.8569 - val_loss: 0.4472 - val_accuracy: 0.8404
# Epoch 35/100
# 11/11 [==============================] - 7s 661ms/step - loss: 0.3887 - accuracy: 0.8573 - val_loss: 0.4553 - val_accuracy: 0.8404
# Epoch 36/100
# 11/11 [==============================] - 7s 656ms/step - loss: 0.3809 - accuracy: 0.8550 - val_loss: 0.5018 - val_accuracy: 0.8404
# Epoch 37/100
# 11/11 [==============================] - 7s 641ms/step - loss: 0.3643 - accuracy: 0.8562 - val_loss: 0.5500 - val_accuracy: 0.8404
# Epoch 38/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.3311 - accuracy: 0.8577 - val_loss: 0.5994 - val_accuracy: 0.8400
# Epoch 39/100
# 11/11 [==============================] - 7s 670ms/step - loss: 0.3019 - accuracy: 0.8561 - val_loss: 0.7575 - val_accuracy: 0.8083
# Epoch 40/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.2703 - accuracy: 0.8630 - val_loss: 0.7506 - val_accuracy: 0.8012
# Epoch 41/100
# 11/11 [==============================] - 7s 645ms/step - loss: 0.2462 - accuracy: 0.8684 - val_loss: 0.8792 - val_accuracy: 0.7629
# Epoch 42/100
# 11/11 [==============================] - 7s 663ms/step - loss: 0.1965 - accuracy: 0.8821 - val_loss: 0.9189 - val_accuracy: 0.7597
# Epoch 43/100
# 11/11 [==============================] - 7s 651ms/step - loss: 0.1581 - accuracy: 0.8941 - val_loss: 1.0900 - val_accuracy: 0.7723
# Epoch 44/100
# 11/11 [==============================] - 7s 653ms/step - loss: 0.1310 - accuracy: 0.9054 - val_loss: 1.2109 - val_accuracy: 0.7725
# Epoch 45/100
# 11/11 [==============================] - 7s 660ms/step - loss: 0.1140 - accuracy: 0.9081 - val_loss: 1.4120 - val_accuracy: 0.7697
# Epoch 46/100
# 11/11 [==============================] - 7s 657ms/step - loss: 0.0976 - accuracy: 0.9147 - val_loss: 1.6320 - val_accuracy: 0.7707
# Epoch 47/100
# 11/11 [==============================] - 7s 643ms/step - loss: 0.0882 - accuracy: 0.9156 - val_loss: 1.5002 - val_accuracy: 0.7651
# Epoch 48/100
# 11/11 [==============================] - 7s 637ms/step - loss: 0.0812 - accuracy: 0.9174 - val_loss: 1.8618 - val_accuracy: 0.7784
# Epoch 49/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0712 - accuracy: 0.9216 - val_loss: 1.9144 - val_accuracy: 0.7766
# Epoch 50/100
# 11/11 [==============================] - 7s 643ms/step - loss: 0.0666 - accuracy: 0.9212 - val_loss: 2.0050 - val_accuracy: 0.7751
# Epoch 51/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.0588 - accuracy: 0.9229 - val_loss: 2.0777 - val_accuracy: 0.7742
# Epoch 52/100
# 11/11 [==============================] - 7s 682ms/step - loss: 0.0552 - accuracy: 0.9233 - val_loss: 2.2758 - val_accuracy: 0.7675
# Epoch 53/100
# 11/11 [==============================] - 7s 652ms/step - loss: 0.0501 - accuracy: 0.9248 - val_loss: 2.6130 - val_accuracy: 0.7859
# Epoch 54/100
# 11/11 [==============================] - 7s 646ms/step - loss: 0.0443 - accuracy: 0.9302 - val_loss: 2.5510 - val_accuracy: 0.7667
# Epoch 55/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0394 - accuracy: 0.9288 - val_loss: 2.7050 - val_accuracy: 0.7688
# Epoch 56/100
# 11/11 [==============================] - 7s 679ms/step - loss: 0.0373 - accuracy: 0.9296 - val_loss: 2.9820 - val_accuracy: 0.7687
# Epoch 57/100
# 11/11 [==============================] - 7s 650ms/step - loss: 0.0328 - accuracy: 0.9310 - val_loss: 3.0149 - val_accuracy: 0.7640
# Epoch 58/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0301 - accuracy: 0.9339 - val_loss: 3.1604 - val_accuracy: 0.7669
# Epoch 59/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.0306 - accuracy: 0.9290 - val_loss: 3.2587 - val_accuracy: 0.7788
# Epoch 60/100
# 11/11 [==============================] - 7s 669ms/step - loss: 0.0287 - accuracy: 0.9332 - val_loss: 3.3666 - val_accuracy: 0.7668
# Epoch 61/100
# 11/11 [==============================] - 7s 657ms/step - loss: 0.0276 - accuracy: 0.9305 - val_loss: 3.4414 - val_accuracy: 0.7542
# Epoch 62/100
# 11/11 [==============================] - 7s 646ms/step - loss: 0.0273 - accuracy: 0.9317 - val_loss: 3.5722 - val_accuracy: 0.7722
# Epoch 63/100
# 11/11 [==============================] - 7s 654ms/step - loss: 0.0250 - accuracy: 0.9361 - val_loss: 3.8309 - val_accuracy: 0.7774
# Epoch 64/100
# 11/11 [==============================] - 7s 652ms/step - loss: 0.0228 - accuracy: 0.9347 - val_loss: 4.0166 - val_accuracy: 0.7721
# Epoch 65/100
# 11/11 [==============================] - 7s 654ms/step - loss: 0.0217 - accuracy: 0.9339 - val_loss: 3.9660 - val_accuracy: 0.7700
# Epoch 66/100
# 11/11 [==============================] - 7s 648ms/step - loss: 0.0203 - accuracy: 0.9346 - val_loss: 4.3123 - val_accuracy: 0.7700
# Epoch 67/100
# 11/11 [==============================] - 7s 654ms/step - loss: 0.0191 - accuracy: 0.9330 - val_loss: 4.4429 - val_accuracy: 0.7725
# Epoch 68/100
# 11/11 [==============================] - 7s 659ms/step - loss: 0.0197 - accuracy: 0.9306 - val_loss: 4.4423 - val_accuracy: 0.7687
# Epoch 69/100
# 11/11 [==============================] - 7s 653ms/step - loss: 0.0174 - accuracy: 0.9362 - val_loss: 4.6738 - val_accuracy: 0.7696
# Epoch 70/100
# 11/11 [==============================] - 7s 643ms/step - loss: 0.0158 - accuracy: 0.9356 - val_loss: 4.7054 - val_accuracy: 0.7748
# Epoch 71/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.0155 - accuracy: 0.9358 - val_loss: 4.9746 - val_accuracy: 0.7719
# Epoch 72/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0158 - accuracy: 0.9340 - val_loss: 5.0734 - val_accuracy: 0.7706
# Epoch 73/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0139 - accuracy: 0.9342 - val_loss: 5.4832 - val_accuracy: 0.7727
# Epoch 74/100
# 11/11 [==============================] - 7s 649ms/step - loss: 0.0129 - accuracy: 0.9355 - val_loss: 5.4188 - val_accuracy: 0.7747
# Epoch 75/100
# 11/11 [==============================] - 7s 648ms/step - loss: 0.0141 - accuracy: 0.9353 - val_loss: 5.5617 - val_accuracy: 0.7706
# Epoch 76/100
# 11/11 [==============================] - 7s 648ms/step - loss: 0.0135 - accuracy: 0.9356 - val_loss: 5.5227 - val_accuracy: 0.7630
# Epoch 77/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0134 - accuracy: 0.9364 - val_loss: 5.6870 - val_accuracy: 0.7627
# Epoch 78/100
# 11/11 [==============================] - 7s 659ms/step - loss: 0.0122 - accuracy: 0.9356 - val_loss: 6.0673 - val_accuracy: 0.7700
# Epoch 79/100
# 11/11 [==============================] - 7s 658ms/step - loss: 0.0112 - accuracy: 0.9371 - val_loss: 5.9604 - val_accuracy: 0.7681
# Epoch 80/100
# 11/11 [==============================] - 7s 652ms/step - loss: 0.0120 - accuracy: 0.9333 - val_loss: 5.9075 - val_accuracy: 0.7676
# Epoch 81/100
# 11/11 [==============================] - 7s 645ms/step - loss: 0.0117 - accuracy: 0.9366 - val_loss: 6.1187 - val_accuracy: 0.7681
# Epoch 82/100
# 11/11 [==============================] - 7s 653ms/step - loss: 0.0120 - accuracy: 0.9354 - val_loss: 6.3634 - val_accuracy: 0.7695
# Epoch 83/100
# 11/11 [==============================] - 7s 647ms/step - loss: 0.0110 - accuracy: 0.9333 - val_loss: 6.5603 - val_accuracy: 0.7647
# Epoch 84/100
# 11/11 [==============================] - 7s 647ms/step - loss: 0.0103 - accuracy: 0.9359 - val_loss: 6.3515 - val_accuracy: 0.7669
# Epoch 85/100
# 11/11 [==============================] - 7s 651ms/step - loss: 0.0107 - accuracy: 0.9356 - val_loss: 6.5070 - val_accuracy: 0.7682
# Epoch 86/100
# 11/11 [==============================] - 7s 664ms/step - loss: 0.0106 - accuracy: 0.9374 - val_loss: 6.7329 - val_accuracy: 0.7649
# Epoch 87/100
# 11/11 [==============================] - 7s 652ms/step - loss: 0.0101 - accuracy: 0.9345 - val_loss: 6.9975 - val_accuracy: 0.7650
# Epoch 88/100
# 11/11 [==============================] - 7s 647ms/step - loss: 0.0100 - accuracy: 0.9367 - val_loss: 7.0194 - val_accuracy: 0.7648
# Epoch 89/100
# 11/11 [==============================] - 7s 657ms/step - loss: 0.0094 - accuracy: 0.9377 - val_loss: 7.1473 - val_accuracy: 0.7703
# Epoch 90/100
# 11/11 [==============================] - 7s 654ms/step - loss: 0.0095 - accuracy: 0.9363 - val_loss: 7.2872 - val_accuracy: 0.7706
# Epoch 91/100
# 11/11 [==============================] - 7s 650ms/step - loss: 0.0096 - accuracy: 0.9361 - val_loss: 6.9746 - val_accuracy: 0.7634
# Epoch 92/100
# 11/11 [==============================] - 7s 653ms/step - loss: 0.0094 - accuracy: 0.9338 - val_loss: 7.1096 - val_accuracy: 0.7663
# Epoch 93/100
# 11/11 [==============================] - 7s 659ms/step - loss: 0.0084 - accuracy: 0.9410 - val_loss: 7.2826 - val_accuracy: 0.7698
# Epoch 94/100
# 11/11 [==============================] - 7s 645ms/step - loss: 0.0086 - accuracy: 0.9358 - val_loss: 7.2408 - val_accuracy: 0.7652
# Epoch 95/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0081 - accuracy: 0.9390 - val_loss: 7.5892 - val_accuracy: 0.7715
# Epoch 96/100
# 11/11 [==============================] - 8s 749ms/step - loss: 0.0079 - accuracy: 0.9387 - val_loss: 7.5592 - val_accuracy: 0.7678
# Epoch 97/100
# 11/11 [==============================] - 7s 655ms/step - loss: 0.0079 - accuracy: 0.9386 - val_loss: 7.6492 - val_accuracy: 0.7676
# Epoch 98/100
# 11/11 [==============================] - 7s 651ms/step - loss: 0.0075 - accuracy: 0.9354 - val_loss: 7.7040 - val_accuracy: 0.7690
# Epoch 99/100
# 11/11 [==============================] - 7s 644ms/step - loss: 0.0075 - accuracy: 0.9352 - val_loss: 7.7910 - val_accuracy: 0.7681
# Epoch 100/100
# 11/11 [==============================] - 7s 646ms/step - loss: 0.0072 - accuracy: 0.9386 - val_loss: 8.0557 - val_accuracy: 0.7683

# %%
model.save(f'UNET-ToothSegmentation_{IMAGE_HEIGHT}_{IMAGE_WIDTH}.h5')

# %%
test_generator = create_segmentation_generator_test(data_dir_test_image, data_dir_test_mask, 1)
# Out:
# Found 30 images belonging to 1 classes.
# Found 30 images belonging to 1 classes.

# %%
def show_prediction(datagen, num=1):
    for i in range(0,num):
        image,mask = next(datagen)
        pred_mask = model.predict(image)[0] > 0.5
        display([image[0], mask[0], pred_mask])

# %%
show_prediction(test_generator, 3)

# %%
# https://github.com/madsendennis/notebooks
