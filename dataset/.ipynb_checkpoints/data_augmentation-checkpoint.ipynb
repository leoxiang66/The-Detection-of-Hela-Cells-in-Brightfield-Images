# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from numpy import expand_dims
from matplotlib import pyplot
from skimage import io
from skimage.io import ImageCollection

# %%
path = 'Center/Center 1.png'

# %% [markdown]
# ### Example of horizontal shift image augmentation

# %%
# load the image
img = load_img(path)
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(width_shift_range=[-2,2])
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ### Example of vertical shift image augmentation

# %%
# load the image
img = load_img(path)
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(height_shift_range=0.2)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ### Example of horizontal/vertical flip image augmentation

# %%
# load the image
img = load_img(path)
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ### Example of random rotation image augmentation

# %%
# load the image
img = load_img(path)
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(rotation_range=90)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ### Example of random rotation image augmentation

# %%
# load the image
img = load_img(path)
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(rotation_range=90)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# - read images

# %%
blank_arr = ImageCollection('Blank/*.png')
border_arr = ImageCollection('Border/*.png')
center_arr = ImageCollection('Center/*.png')
len(blank_arr), len(border_arr), len(center_arr)
# Out:
# (32, 25, 32)

# %% [markdown]
# - data augmentation function

# %%
def da(img):
    # convert to numpy array
    data = img_to_array(img)
    # expand dimension to one sample
    samples = expand_dims(data, 0)
    # create image data augmentation generator
    
    # horizontal shift
    datagen = ImageDataGenerator(width_shift_range=[-2,2])
    # prepare iterator
    it = datagen.flow(samples, batch_size=1)
    # generate samples and plot
    for i in range(9):
        # generate batch of images
        batch = it.next()
        # convert to unsigned integers for viewing
        image = batch[0]
        io.imsave(f'temp\abc_{i}.tif',image)
        
io.show()

# %% [markdown]
# 1) data augmention of blank images

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-70b96f95600d> in <module>
# ----> 1 da(blank_arr[0])
#
# <ipython-input-16-3023c2a13210> in da(img)
#      16         # convert to unsigned integers for viewing
#      17         image = batch[0]
# ---> 18         io.imsave('temp',image)
#      19
#      20 io.show()
#
# D:\documents\anaconda\lib\site-packages\skimage\io\_io.py in imsave(fname, arr, plugin, check_contrast, **plugin_args)
#     134     if check_contrast and is_low_contrast(arr):
#     135         warn('%s is a low contrast image' % fname)
# --> 136     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#     137
#     138
#
# D:\documents\anaconda\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     207                                (plugin, kind))
#     208
# --> 209     return func(*args, **kwargs)
#     210
#     211
#
# D:\documents\anaconda\lib\site-packages\imageio\core\functions.py in imwrite(uri, im, format, **kwargs)
#     301
#     302     # Get writer and write first
# --> 303     writer = get_writer(uri, format, "i", **kwargs)
#     304     with writer:
#     305         writer.append_data(im)
#
# D:\documents\anaconda\lib\site-packages\imageio\core\functions.py in get_writer(uri, format, mode, **kwargs)
#     224     if format is None:
#     225         modename = MODENAMES.get(mode, mode)
# --> 226         raise ValueError(
#     227             "Could not find a format to write the specified file in %s mode" % modename
#     228         )
#
# ValueError: Could not find a format to write the specified file in single-image mode
