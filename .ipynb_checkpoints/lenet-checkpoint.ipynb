# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from skimage.io import ImageCollection
from pprint import pprint
from skimage import io
import numpy as np

# %%
def readAllImages(path):
    img_arr = ImageCollection(path + '/*.png')
    return img_arr,len(img_arr)

# %%
# 读取数据
blank = readAllImages('''Classify 4/Blank_aug''')
border = readAllImages('''Classify 4/Border_aug''')
center = readAllImages('''Classify 4/Center_aug''')

arr1,len1 = blank[0],blank[1]   # 2
arr2,len2 = border[0],border[1]  # 0
arr3,len3 = center[0],center[1] # 1






train_images = []
test_images = []
train_y = []
test_y = []

for i in range(len1):
    if i >= 400:
        test_images.append(arr1[i])
        test_y.append(2)
    else:
        train_images.append(arr1[i])
        train_y.append(2)

for i in range(len2):
    if i >= 400:
        test_images.append(arr2[i])
        test_y.append(0)
    else:
        train_images.append(arr2[i])
        train_y.append(0)
        
for i in range(len3):
    if i >= 400:
        test_images.append(arr3[i])
        test_y.append(1)
    else:
        train_images.append(arr3[i])
        train_y.append(1)


y_train = np.array(train_y,dtype='int32')
y_test = np.array(test_y,dtype='int32')
x_train = np.stack(train_images,axis=0)
x_test = np.stack(test_images,axis=0)

print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1200, 20, 20, 3) (299, 20, 20, 3)
# (1200,) (299,)

# %%
# 数据预处理函数
def preprocess(x, y):
    x = tf.cast(x, dtype=tf.float32) / 255.
    x = tf.reshape(x, [-1, 32, 32, 3])
    y = tf.one_hot(y, depth=3)  # one_hot 编码
    return x, y

# %%
# 样本图像周围补0（上下左右均补6个0），将20*20的图像转成32*32的图像
paddings = tf.constant([[0,0],[6, 6], [6, 6], [0, 0]])
x_train = tf.pad(x_train, paddings)
x_test = tf.pad(x_test, paddings)

x_train.shape, x_test.shape
# Out:
# (TensorShape([1200, 32, 32, 3]), TensorShape([299, 32, 32, 3]))

# %%
train_db = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_db = train_db.shuffle(10000)  # 打乱训练集样本
train_db = train_db.batch(128)
train_db = train_db.map(preprocess)

test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_db = test_db.shuffle(10000)  # 打乱测试集样本
test_db = test_db.batch(128)
test_db = test_db.map(preprocess)

batch = 32

# %%
# 创建模型
model = keras.Sequential([
    # 卷积层1
    keras.layers.Conv2D(6, 5),  # 使用6个5*5的卷积核对单通道32*32的图片进行卷积，结果得到6个28*28的特征图
    keras.layers.MaxPooling2D(pool_size=2, strides=2),  # 对28*28的特征图进行2*2最大池化，得到14*14的特征图
    keras.layers.ReLU(),  # ReLU激活函数
    # 卷积层2
    keras.layers.Conv2D(16, 5),  # 使用16个5*5的卷积核对6通道14*14的图片进行卷积，结果得到16个10*10的特征图
    keras.layers.MaxPooling2D(pool_size=2, strides=2),  # 对10*10的特征图进行2*2最大池化，得到5*5的特征图
    keras.layers.ReLU(),  # ReLU激活函数
    # 卷积层3
    keras.layers.Conv2D(120, 5),  # 使用120个5*5的卷积核对16通道5*5的图片进行卷积，结果得到120个1*1的特征图
    keras.layers.ReLU(),  # ReLU激活函数
    # 将 (None, 1, 1, 120) 的下采样图片拉伸成 (None, 120) 的形状
    keras.layers.Flatten(),
    # 全连接层1
    keras.layers.Dense(84, activation='relu'),  # 120*84
    # 全连接层2
    keras.layers.Dense(3, activation='softmax')  # 84*10
])
model.build(input_shape=(batch, 32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (32, 28, 28, 6)           456
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (32, 14, 14, 6)           0
# _________________________________________________________________
# re_lu (ReLU)                 (32, 14, 14, 6)           0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (32, 10, 10, 16)          2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (32, 5, 5, 16)            0
# _________________________________________________________________
# re_lu_1 (ReLU)               (32, 5, 5, 16)            0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (32, 1, 1, 120)           48120
# _________________________________________________________________
# re_lu_2 (ReLU)               (32, 1, 1, 120)           0
# _________________________________________________________________
# flatten (Flatten)            (32, 120)                 0
# _________________________________________________________________
# dense (Dense)                (32, 84)                  10164
# _________________________________________________________________
# dense_1 (Dense)              (32, 3)                   255
# =================================================================
# Total params: 61,411
# Trainable params: 61,411
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.Adam(), loss=keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
# 训练
history = model.fit(train_db, epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 26ms/step - loss: 0.8220 - accuracy: 0.7633
# Epoch 2/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2778 - accuracy: 0.8788
# Epoch 3/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.1529 - accuracy: 0.9470
# Epoch 4/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1161 - accuracy: 0.9631
# Epoch 5/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.1157 - accuracy: 0.9614
# Epoch 6/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1102 - accuracy: 0.9624
# Epoch 7/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1078 - accuracy: 0.9617
# Epoch 8/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1002 - accuracy: 0.9711
# Epoch 9/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0861 - accuracy: 0.9773
# Epoch 10/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0913 - accuracy: 0.9749
# Epoch 11/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0858 - accuracy: 0.9765
# Epoch 12/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0779 - accuracy: 0.9779
# Epoch 13/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0756 - accuracy: 0.9788
# Epoch 14/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0626 - accuracy: 0.9877
# Epoch 15/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0631 - accuracy: 0.9826
# Epoch 16/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0673 - accuracy: 0.9855
# Epoch 17/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1045 - accuracy: 0.9577
# Epoch 18/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1005 - accuracy: 0.9651
# Epoch 19/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1051 - accuracy: 0.9581
# Epoch 20/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0837 - accuracy: 0.9772
# Epoch 21/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0636 - accuracy: 0.9835
# Epoch 22/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0511 - accuracy: 0.9912
# Epoch 23/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0500 - accuracy: 0.9916
# Epoch 24/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0506 - accuracy: 0.9885
# Epoch 25/100
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0439 - accuracy: 0.9901
# Epoch 26/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0551 - accuracy: 0.9842
# Epoch 27/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0442 - accuracy: 0.9903
# Epoch 28/100
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0451 - accuracy: 0.9900
# Epoch 29/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0771 - accuracy: 0.9676
# Epoch 30/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.1213 - accuracy: 0.9454
# Epoch 31/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0548 - accuracy: 0.9851
# Epoch 32/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0505 - accuracy: 0.9821
# Epoch 33/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0512 - accuracy: 0.9888
# Epoch 34/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0524 - accuracy: 0.9835
# Epoch 35/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0506 - accuracy: 0.9870
# Epoch 36/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0554 - accuracy: 0.9790
# Epoch 37/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0393 - accuracy: 0.9889
# Epoch 38/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0290 - accuracy: 0.9939
# Epoch 39/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0258 - accuracy: 0.9985
# Epoch 40/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0233 - accuracy: 0.9979
# Epoch 41/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0243 - accuracy: 0.9994
# Epoch 42/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0239 - accuracy: 0.9956
# Epoch 43/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0239 - accuracy: 0.9969
# Epoch 44/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0678 - accuracy: 0.9735
# Epoch 45/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0369 - accuracy: 0.9901
# Epoch 46/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0313 - accuracy: 0.9945
# Epoch 47/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0276 - accuracy: 0.9960
# Epoch 48/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0372 - accuracy: 0.9875
# Epoch 49/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0217 - accuracy: 0.9967
# Epoch 50/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 52/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 53/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 54/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 56/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0141 - accuracy: 0.9976
# Epoch 58/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0207 - accuracy: 0.9944
# Epoch 59/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0054 - accuracy: 1.0000 0s - loss: 0.0055 - accuracy: 1.
# Epoch 68/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0018 - accuracy: 1.0000

# %%
# 损失下降曲线
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# 测试
model.evaluate(test_db)
# Out:
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3033 - accuracy: 0.9231
# [0.30328285694122314, 0.9230769276618958]
