# %% [markdown]
# ### imports

# %%
from skimage import io
import numpy as np
from pprint import pprint

# %% [markdown]
# ### load image

# %%
img = io.imread('/Users/taoxiang/Downloads/BF-C2DL-HSC/01/t0000.tif' )

# %% [markdown]
# ### Image shape: 2D

# %%
rows,cols =  img.shape
print('shape:',img.shape)
print('values:')
pprint(img)
# Out:
# shape: (1010, 1010)
# values:
# array([[132, 130, 130, ..., 126, 124, 125],
#        [132, 132, 132, ..., 125, 125, 126],
#        [130, 130, 131, ..., 126, 126, 125],
#        ...,
#        [139, 139, 139, ..., 117, 117, 118],
#        [138, 138, 139, ..., 120, 120, 119],
#        [140, 139, 139, ..., 116, 118, 117]], dtype=uint8)

# %% [markdown]
# ### Original image

# %%
io.imshow(img)

# %% [markdown]
# ### Example to modify the image

# %%
for i in range(5000):
    x = np.random.randint(rows)
    y = np.random.randint(cols)
    img[x,y] = 255

io.imshow(img)

# %% [markdown]
# ### Display

# %%
io.show()
